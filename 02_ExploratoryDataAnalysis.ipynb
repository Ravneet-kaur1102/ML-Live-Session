# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravneet-kaur1102/ML-Live-Session/blob/main/02_ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Author: Ravneet Kaur
#
# Date: June 4, 2021
#
# Reach me at: [LinkedIn](https://www.linkedin.com/in/ravneet-kaur-4b018b45/)
#
# For DataSet: [Data Set](https://archive.ics.uci.edu/ml/machine-learning-databases/00320/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/AI Live Session'
# Out:
# /content/drive/MyDrive/AI Live Session

# %%
ls
# Out:
# 02_ExploratoryDataAnalysis.ipynb  June_06_2021.ipynb
# Files/                            Perceptrons_01.ipynb

# %%
cd Files
# Out:
# [Errno 2] No such file or directory: 'Files'
# /content/drive/MyDrive/AI Live Session/Files

# %%
ls
# Out:
# cleanedMathData.csv  student-merge.R  student.txt
# student-mat.csv      student-por.csv

# %%
import pandas as pd
pd.read_csv('student-mat.csv')
# Out:
#     school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3
# 0    GP;"F";18;"U";"GT3";"A";4;4;"at_home";"teacher...
# 1    GP;"F";17;"U";"GT3";"T";1;1;"at_home";"other";...
# 2    GP;"F";15;"U";"LE3";"T";1;1;"at_home";"other";...
# 3    GP;"F";15;"U";"GT3";"T";4;2;"health";"services...
# 4    GP;"F";16;"U";"GT3";"T";3;3;"other";"other";"h...
# ..                                                 ...
# 390  MS;"M";20;"U";"LE3";"A";2;2;"services";"servic...
# 391  MS;"M";17;"U";"LE3";"T";3;1;"services";"servic...
# 392  MS;"M";21;"R";"GT3";"T";1;1;"other";"other";"c...
# 393  MS;"M";18;"R";"LE3";"T";3;2;"services";"other"...
# 394  MS;"M";19;"U";"LE3";"T";1;1;"other";"at_home";...
#
# [395 rows x 1 columns]

# %%
pd.read_csv('student-mat.csv',sep=';')
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
import pandas as pd #working with csv or excel
import numpy as np  #working with numbers/arrays/tensors
import tensorflow as tf #its a framework
from tensorflow import keras #API/library
import os #using os command between python language

# %%
mathData = pd.read_csv('student-mat.csv', sep=';') #loading the file in mathData to perform other operations

# %%
mathData
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0       GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1       GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2       GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3       GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4       GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# ..     ...  ..  ...     ...     ...     ...  ...   ...     ...      ...  ..  ..  ..
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
mathData.head(10) #prints the first 10 rows of the dataframe
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6     GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7     GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8     GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9     GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
#
# [10 rows x 33 columns]

# %%
mathData.tail()
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
mathData.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
mathData.columns
# Out:
# Index(['school', 'address', 'romantic', 'sex', 'higher', 'Mjob', 'Fjob',
#        'nursery'],
#       dtype='object')

# %%
print(f'school: {mathData.school.unique()}')
print(f'romantic:{mathData.romantic.unique()}')
print(f'sex:{mathData.sex.unique()}')
print(f'nursery:{mathData.nursery.unique()}')
print(f'address:{mathData.address.unique()}')
print(f'Mjob:{mathData.Mjob.unique()}')
print(f'Fjob:{mathData.Fjob.unique()}')
print(f'higher:{mathData.higher.unique()}')
# Out:
# school: ['GP' 'MS']
# romantic:['no' 'yes']
# sex:['F' 'M']
# nursery:['yes' 'no']
# address:['U' 'R']
# Mjob:['at_home' 'health' 'other' 'services' 'teacher']
# Fjob:['teacher' 'other' 'services' 'health' 'at_home']
# higher:['yes' 'no']

# %%
# convert categories into column

#binary valued

mathData['school']=mathData['school'].apply({'GP':1, 'MS':2}.get)
mathData['romantic'] = mathData['romantic'].apply({'yes':1,'no':2}.get)
mathData['sex']=mathData['sex'].apply({'F':1,'N':2}.get)
mathData['nursery']=mathData['nursery'].apply({'yes':1,'no':2}.get)
mathData['address']=mathData['address'].apply({'U':1,'R':2}.get)

#multivalued
mathData['Mjob']=mathData['Mjob'].apply({'at_home':1,'health':2,'other':3,'services':4,'teacher':5}.get)
mathData['Fjob']=mathData['Fjob'].apply({'at_home':1,'health':2,'other':3,'services':4,'teacher':5}.get)

mathData.head(5)
# Out:
#    school  sex  age  address famsize  ... health  absences  G1  G2  G3
# 0       1  1.0   18        1     GT3  ...      3         6   5   6   6
# 1       1  1.0   17        1     GT3  ...      3         4   5   5   6
# 2       1  1.0   15        1     LE3  ...      3        10   7   8  10
# 3       1  1.0   15        1     GT3  ...      5         2  15  14  15
# 4       1  1.0   16        1     GT3  ...      5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
# to print particular columns

mathData= mathData[['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime', 'studytime', 'absences', 'G1', 'G2', 'G3']]

# %%
mathData.head(5)
# Out:
#    school  address  romantic  sex higher  Mjob  Fjob  nursery
# 0       1        1         2  1.0    yes     1     5        1
# 1       1        1         2  1.0    yes     1     3        2
# 2       1        1         2  1.0    yes     1     3        1
# 3       1        1         1  1.0    yes     2     4        1
# 4       1        1         2  1.0    yes     3     3        1

# %% [markdown]
# # Data Visualisation

# %%
import seaborn as sns
sns.palplot(sns.color_palette('PuOr')) #Purple to Orange colors
pal = sns.color_palette('PuOr', 6) #print 6 color shades from Purple to Orange
pal.as_hex() #set hex code values for colors

import matplotlib.pyplot as plt
plt.style.use(['seaborn'])
sns_colors = ['#c6690c', '#664697'] #orange Purple hex codes
sns.set_palette(sns_colors) #set the palette as sns_colors 
sns.palplot(sns.color_palette(sns_colors)) #plot the color codes

# %%
print(f'''There are {len(mathData.columns)} columns in the dataframe mathData namely,

{mathData.columns}''') #columns in the dataframe
# Out:
# There are 12 columns in the dataframe mathData namely,
#
# Index(['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
#        'studytime', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.pairplot(mathData,
             x_vars = [ 'G3', 'freetime', 'studytime', 'absences' ],
             y_vars = ['G1', 'G2', 'G3'],
       diag_kind='kde', hue='G3'
             )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#pairplot for all the values

sns.pairplot(mathData,
             x_vars = ['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
       'studytime', 'absences', 'G1', 'G2'],
             y_vars = ['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
       'studytime', 'absences', 'G1', 'G2' ],
       diag_kind='kde', hue='G3'
             )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7c9b4bb45109> in <module>()
#       6              y_vars = ['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
#       7        'studytime', 'absences', 'G1', 'G2' ],
# ----> 8        diag_kind='kde', hue='G3'
#       9              )
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2020     elif diag_kind == "kde":
#    2021         diag_kws.setdefault("fill", True)
# -> 2022         grid.map_diag(kdeplot, **diag_kws)
#    2023
#    2024     # Maybe plot on the off-diagonals
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1400             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1401             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1402             func(x=vector, **plot_kwargs)
#    1403             self._clean_axis(ax)
#    1404
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1718     )
#    1719
# -> 1720     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1721
#    1722     if p.univariate:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in _attach(self, obj, allowed_types, log_scale)
#    1116                     f"{allowed_types} is required"
#    1117                 )
# -> 1118                 raise TypeError(err)
#    1119
#    1120             # Register with the matplotlib unit conversion machinery
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %% [markdown]
# # Strip Plot-->Plotting a graph

# %%
sns.stripplot(y='G1', x='G2', data=mathData)

# %% [markdown]
# ##ploting multiple graphs

# %%
# stripplots plotted as subplots on one main plot with the ax parameter

fig, axarr = plt.subplots(3,2, figsize=(20,20))

#three rows and 2 columns all starting from (0,0)

sns.stripplot(y='G1', x='G2', data=mathData, hue=None, ax=axarr[0][0])
sns.stripplot(y='G1', x='G3', data=mathData, hue=None, ax=axarr[1][1])
sns.stripplot(y='studytime', x='G3', data=mathData, hue=None, ax=axarr[1][0])
sns.stripplot(y='freetime', x='G3', data=mathData, hue=None,  ax=axarr[0][1])
sns.stripplot(y='higher', x='G3', data=mathData, hue=None, ax=axarr[2][0])
sns.stripplot(y='absences', x='G3', data=mathData, hue=None, ax=axarr[2][1])

# %% [markdown]
# ##Data Split

# %%
#80-20 train-test percent split

trainDataset = mathData.sample(frac=0.8, random_state=0) 
testDataset = mathData.drop(trainDataset.index)

print(trainDataset.head())
print(testDataset.head())
# Out:
#      school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 329       1  1.0        1     5     5  ...         3         4  14  14  14
# 318       1  1.0        2     1     4  ...         3         0  11  11  10
# 317       1  1.0        1     3     3  ...         3         9   9  10   9
# 65        1  1.0        1     5     4  ...         2         2  16  15  15
# 59        1  1.0        1     4     3  ...         2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 9        1  NaN        1     3     3  ...         2         0  14  15  15
# 25       1  1.0        1     4     4  ...         1        14   6   9   8
# 28       1  NaN        1     4     3  ...         2         4  11  11  11
# 31       1  NaN        1     4     4  ...         2         0  17  16  17
# 32       1  NaN        2     5     1  ...         2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
print(trainDataset.shape)
print(testDataset.shape)
# Out:
# (316, 12)
# (79, 12)

# %%
#copy the trainDataset dataframe for getting the features

trainFeatures = trainDataset.copy()
testFeatures = testDataset.copy()

print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 329       1  1.0        1     5     5  ...         3         4  14  14  14
# 318       1  1.0        2     1     4  ...         3         0  11  11  10
# 317       1  1.0        1     3     3  ...         3         9   9  10   9
# 65        1  1.0        1     5     4  ...         2         2  16  15  15
# 59        1  1.0        1     4     3  ...         2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 9        1  NaN        1     3     3  ...         2         0  14  15  15
# 25       1  1.0        1     4     4  ...         1        14   6   9   8
# 28       1  NaN        1     4     3  ...         2         4  11  11  11
# 31       1  NaN        1     4     4  ...         2         0  17  16  17
# 32       1  NaN        2     5     1  ...         2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
#copy the trainDataset dataframe for getting the features

trainFeatures = trainDataset.copy()
testFeatures = testDataset.copy()

print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 329       1  1.0        1     5     5  ...         3         4  14  14  14
# 318       1  1.0        2     1     4  ...         3         0  11  11  10
# 317       1  1.0        1     3     3  ...         3         9   9  10   9
# 65        1  1.0        1     5     4  ...         2         2  16  15  15
# 59        1  1.0        1     4     3  ...         2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 9        1  NaN        1     3     3  ...         2         0  14  15  15
# 25       1  1.0        1     4     4  ...         1        14   6   9   8
# 28       1  NaN        1     4     3  ...         2         4  11  11  11
# 31       1  NaN        1     4     4  ...         2         0  17  16  17
# 32       1  NaN        2     5     1  ...         2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 329       1  1.0        1     5     5  ...         3         4  14  14  14
# 318       1  1.0        2     1     4  ...         3         0  11  11  10
# 317       1  1.0        1     3     3  ...         3         9   9  10   9
# 65        1  1.0        1     5     4  ...         2         2  16  15  15
# 59        1  1.0        1     4     3  ...         2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ... studytime  absences  G1  G2  G3
# 9        1  NaN        1     3     3  ...         2         0  14  15  15
# 25       1  1.0        1     4     4  ...         1        14   6   9   8
# 28       1  NaN        1     4     3  ...         2         4  11  11  11
# 31       1  NaN        1     4     4  ...         2         0  17  16  17
# 32       1  NaN        2     5     1  ...         2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
print(testFeatures.shape)
# Out:
# (79, 12)
